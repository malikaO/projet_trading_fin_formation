# %%
#pip install webdriver-manager

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
import time
from selenium import webdriver
import pandas as pd

# %%
#browser = webdriver.Chrome(executable_path=r'C:\Users\utilisateur\.wdm\drivers\chromedriver\win32\85.0.4183.87\chromedriver.exe')
browser = webdriver.Chrome()
company = 'google'
browser.get(f'https://seekingalpha.com/search?q={company}&tab=news#10')



#time.sleep(1)
masterdf = pd.DataFrame(columns=["title", "Date", "comment"])

for page in range(287,400):
    browser.get(" https://seekingalpha.com/search?q=google&tab=news#page={}".format(page))
    time.sleep(5)
    page_url = browser.current_url
    temp_title_names = browser.find_elements_by_xpath('//*[@id="result_list"]/ul/li[1]/div[2]/div[1]/a')
    for title in range(len(temp_title_names)):
        tempdf=pd.DataFrame()
        df_titles = browser.find_elements_by_xpath('//*[@id="result_list"]/ul/li[1]/div[2]/div[1]/a')
        element = df_titles[title]
        if element.text not in masterdf.title:
            browser.execute_script("arguments[0].click();", element)
            time.sleep(5)
            
            try:  
                Date =browser.find_element_by_xpath('//*[@id="result_list"]/ul/li[2]/div[2]/div[2]').text
                tempdf.loc[0,"Date"] = Date.replace('\n','')
            except NoSuchElementException:
                pass 
            try:  
                comment =browser.find_element_by_xpath('//*[@id="result_list"]/ul/li[1]/div[2]/div[1]/a').text
                tempdf.loc[0,"comment"] = comment.replace('\n','')
            except NoSuchElementException:
                pass 
            
            
            masterdf = masterdf.append(tempdf)
            browser.get(page_url)
            time.sleep(5)
        else:
            pass
    
        
#masterdf.to_csv("scrape_results.csv")
display(masterdf)
# Out:
#    title                                         Date  \
# 0    NaN        GOOGL, GOOGThursday, October 1st 2020
# 0    NaN                 GOOGThursday, July 19th 2012
# 0    NaN        GOOGL, GOOGTuesday, January 22nd 2019
# 0    NaN        GOOG, AUO, AAPLFriday, June 29th 2012
# 0    NaN      GOOG, AAPLWednesday, February 16th 2011
# ..   ...                                          ...
# 0    NaN
# 0    NaN       AABA, GOOG, MSFTTuesday, June 3rd 2008
# 0    NaN  GOOGL, GOOG, MSFT, FBFriday, July 13th 2018
# 0    NaN             GOOGL, GOOGFriday, June 2nd 2017
# 0    NaN             GOOGL, GOOGFriday, June 2nd 2017
#
#                                               comment
# 0   Google pauses News Showcase launch in Australi...
# 0   Vringo (VRNG) -2.7% AH after SA contributor Pa...
# 0   Google (NASDAQ:GOOG) and Facebook (NASDAQ:FB) ...
# 0   Google Chrome (NASDAQ:GOOG) has passed Interne...
# 0   Google (NASDAQ:GOOG) acquires eReader platform...
# ..                                                ...
# 0
# 0   Google (NASDAQ:GOOG), Microsoft (NASDAQ:MSFT),...
# 0             YouTube TV expands virtually nationwide
# 0             Washington state sues over election ads
# 0             Washington state sues over election ads
#
# [113 rows x 3 columns]

# %%
masterdf
# Out:
#    title                                         Date  \
# 0    NaN        GOOGL, GOOGThursday, October 1st 2020
# 0    NaN                 GOOGThursday, July 19th 2012
# 0    NaN        GOOGL, GOOGTuesday, January 22nd 2019
# 0    NaN        GOOG, AUO, AAPLFriday, June 29th 2012
# 0    NaN      GOOG, AAPLWednesday, February 16th 2011
# ..   ...                                          ...
# 0    NaN
# 0    NaN       AABA, GOOG, MSFTTuesday, June 3rd 2008
# 0    NaN  GOOGL, GOOG, MSFT, FBFriday, July 13th 2018
# 0    NaN             GOOGL, GOOGFriday, June 2nd 2017
# 0    NaN             GOOGL, GOOGFriday, June 2nd 2017
#
#                                               comment
# 0   Google pauses News Showcase launch in Australi...
# 0   Vringo (VRNG) -2.7% AH after SA contributor Pa...
# 0   Google (NASDAQ:GOOG) and Facebook (NASDAQ:FB) ...
# 0   Google Chrome (NASDAQ:GOOG) has passed Interne...
# 0   Google (NASDAQ:GOOG) acquires eReader platform...
# ..                                                ...
# 0
# 0   Google (NASDAQ:GOOG), Microsoft (NASDAQ:MSFT),...
# 0             YouTube TV expands virtually nationwide
# 0             Washington state sues over election ads
# 0             Washington state sues over election ads
#
# [113 rows x 3 columns]

# %%
masterdf.shape
# Out:
# (113, 3)

# %%
masterdf.to_csv("google_newssss3.csv")
