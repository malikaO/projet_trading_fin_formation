# %% [markdown]
# # Projet trading
#
# ## Partie 1: Récupération des prix

# %% [markdown]
# **Secteur d’activité du numérique** :
#
# - Microsoft (MSFT)
# - Google     (GOOG)
# - Amazon   ( AMZN)
#
#
# https://www.kaggle.com/faressayah/stock-market-analysis-prediction-using-lstm/notebook

# %%
import matplotlib.pyplot as plt
import pandas as pd
import datetime as dt
import numpy as np
import math

# %%
#pip install yfinance

# %% [markdown]
# ## Récupération des prix en utilisant Yahoo's Finance API

# %%
import yfinance as yf

msft = yf.Ticker("MSFT")

# get stock info
#print(msft.info)

# %% [markdown]
# ## Chargement des données
#
# On travail sur les données des dix dérnières années.

# %%
# Microsoft
tickerSymbol = "MSFT"
tickerData = yf.Ticker(tickerSymbol)
msft = tickerData.history(period='1d', start='2010-10-1', end="2020-9-29")

# %%
msft
# Out:
#               Open    High     Low   Close    Volume  Dividends  Stock Splits
# Date
# 2010-09-30   19.50   19.67   19.30   19.40  61262700        0.0             0
# 2010-10-01   19.62   19.66   19.25   19.32  62672300        0.0             0
# 2010-10-04   18.98   19.01   18.84   18.94  98143400        0.0             0
# 2010-10-05   19.06   19.37   18.94   19.29  78152900        0.0             0
# 2010-10-06   19.27   19.44   19.12   19.36  50489700        0.0             0
# ...            ...     ...     ...     ...       ...        ...           ...
# 2020-09-22  205.06  208.10  202.08  207.42  33517100        0.0             0
# 2020-09-23  207.90  208.10  200.03  200.59  30803800        0.0             0
# 2020-09-24  199.85  205.57  199.20  203.19  31202500        0.0             0
# 2020-09-25  203.55  209.04  202.54  207.82  29437300        0.0             0
# 2020-09-28  210.88  212.57  208.06  209.44  31948300        0.0             0
#
# [2516 rows x 7 columns]

# %%
# Google
tickerSymbol = "GOOG"
tickerData = yf.Ticker(tickerSymbol)
goog = tickerData.history(period='1d', start='2010-10-1', end="2020-9-29")

# %%
goog
# Out:
#                Open     High      Low    Close   Volume  Dividends  \
# Date
# 2010-09-30   263.59   264.94   258.49   261.91  6512400          0
# 2010-10-01   264.01   264.32   260.52   261.83  4466600          0
# 2010-10-04   261.49   263.14   258.46   260.20  3895400          0
# 2010-10-05   263.20   268.99   262.29   268.11  7040400          0
# 2010-10-06   268.62   268.97   263.98   266.18  5545200          0
# ...             ...      ...      ...      ...      ...        ...
# 2020-09-22  1450.09  1469.52  1434.53  1465.46  1583200          0
# 2020-09-23  1458.78  1460.96  1407.70  1415.21  1657400          0
# 2020-09-24  1411.03  1443.71  1409.85  1428.29  1450200          0
# 2020-09-25  1432.63  1450.00  1413.34  1444.96  1323000          0
# 2020-09-28  1474.21  1476.80  1449.30  1464.52  2006200          0
#
#             Stock Splits
# Date
# 2010-09-30           0.0
# 2010-10-01           0.0
# 2010-10-04           0.0
# 2010-10-05           0.0
# 2010-10-06           0.0
# ...                  ...
# 2020-09-22           0.0
# 2020-09-23           0.0
# 2020-09-24           0.0
# 2020-09-25           0.0
# 2020-09-28           0.0
#
# [2516 rows x 7 columns]

# %%
# Amazon
tickerSymbol = "AMZN"
tickerData = yf.Ticker(tickerSymbol)
amzn = tickerData.history(period='1d', start='2010-10-1', end="2020-9-29")

# %%
amzn
# Out:
#                Open     High      Low    Close   Volume  Dividends  \
# Date
# 2010-09-30   160.01   160.93   155.60   157.06  7606000          0
# 2010-10-01   157.08   157.44   152.20   153.71  8683400          0
# 2010-10-04   153.95   155.96   152.79   155.39  5346500          0
# 2010-10-05   157.08   161.21   157.01   160.87  5620000          0
# 2010-10-06   160.60   160.68   154.60   155.40  6060800          0
# ...             ...      ...      ...      ...      ...        ...
# 2020-09-22  3033.84  3133.99  3000.20  3128.99  6948800          0
# 2020-09-23  3120.43  3127.00  2992.38  2999.86  5652700          0
# 2020-09-24  2977.79  3069.30  2965.00  3019.79  5529400          0
# 2020-09-25  3054.86  3101.54  2999.00  3095.13  4615200          0
# 2020-09-28  3148.85  3175.04  3117.17  3174.05  4205100          0
#
#             Stock Splits
# Date
# 2010-09-30             0
# 2010-10-01             0
# 2010-10-04             0
# 2010-10-05             0
# 2010-10-06             0
# ...                  ...
# 2020-09-22             0
# 2020-09-23             0
# 2020-09-24             0
# 2020-09-25             0
# 2020-09-28             0
#
# [2516 rows x 7 columns]

# %%
msft.to_csv('microsoft.csv')

# %%
goog.to_csv('google.csv')

# %%
amzn.to_csv('amazon.csv')
